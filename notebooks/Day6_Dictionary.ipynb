# %%
lst= ["a@gmail.com","b@gmail.com","c@gmail.com"]
lst[1]
# Out:
# 'b@gmail.com'

# %% [markdown]
# # Json Format

# %%
#json format is kind of dictionary
data={
  "name": "John Doe",
  "age": 30,
  "isEmployee": True,
  "hobbies": ["reading", "coding"],
  "address": {
    "city": "New York",
    "zip": "10001"
  }
}
# Out:
# <class 'dict'>

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
#in dictionary how it differ from json
id=keys
101=value

# %% [markdown]
# # Dictionary

# %%
dict=({"name":"Bijaya","Roll":1})
dict
# Out:
# {'name': 'Bijaya', 'Roll': 1}

# %%
#this i tried but failed
student=dict(({sstudent1{'name':'Bijaya','age':26}},{sstudent2{'name':'Paudel','age':25}}))
# Out:
#   File "/tmp/ipykernel_1656/4201525841.py", line 2
#     student=dict(({sstudent1{'name':'Bijaya','age':26}},{sstudent2{'name':'Paudel','age':25}}))
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# this is solution
students= dict({
    'student1':dict({'name':'Bijaya','age':26}),
    'student2':dict({'name':'Paudel','age':25})
})
students

#value are unique
#key can be common
#here format is key:value
#key neednot be string

eg #{ 1:"Bijaya"}
# Out:
# {'student1': {'name': 'Bijaya', 'age': 26},
#  'student2': {'name': 'Paudel', 'age': 25}}

# %% [markdown]
# # Example of dictionary

# %%
#create a dict from seq as pair
person= dict([
    ('name','Bijaya'),
    ('country','Nepal'),
    ('Telephone','9847583')])
print(person)

#this is pair-no curly, no colon


#pro tip:use json parser online to check code correctness of json
# Out:
# {'name': 'Bijaya', 'country': 'Nepal', 'Telephone': '9847583'}

# %% [markdown]
# # Dictionary access

# %%
data_new = {
    'name':'Bijaya',
    'age':26
}
data_new
# Out:
# {'name': 'Bijaya', 'age': 26}

# %%
#accessing data
data_new['name']
# Out:
# 'Bijaya'

# %% [markdown]
# # Using get,changing dict values

# %%
#using get

data_new.get('name')
# Out:
# 'Bijaya'

# %%
data_new['name']= 'Paudel'
data_new
# Out:
# {'name': 'Paudel', 'age': 26}

# %% [markdown]
# # Dict methods

# %%
#gives keys
data_new.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
#gives values
data_new.values()
# Out:
# dict_values(['Paudel', 26])

# %%
#list all dict
data_new.items()
# Out:
# dict_items([('name', 'Paudel'), ('age', 26)])

# %%
#pop
data_new.pop('age')
# Out:
# 26

# %%
#pop item
data_new = {
    'name':'Bijaya',
    'age':26
}
data_new.popitem()
# Out:
# ('age', 26)

# %%
#del key
data_new = {
    'name':'Bijaya',
    'age':26
}
del data_new['name']
data_new
# Out:
# {'age': 26}

# %%
#clear
data_new.clear()
data_new
# Out:
# {}

# %%
del data_new

# %% [markdown]
# # del vs pop

# %%
data= {'phone':'samsung'}
del data['phone']
data
# Out:
# {}

# %%
data= {'phone':'samsung'}
data.pop('phone')
data
# Out:
# {}

# %%
#pop ma message dekhauna milx
data.pop('phone','not found')
# Out:
# 'not found'

# %% [markdown]
# # Join two dict

# %%
#update

dict1= {'name':'Bijaya'}
dict2= {'roll':21}
dict1.update(dict2)
dict1
# Out:
# {'name': 'Bijaya', 'roll': 21}

# %%
dict1= {'name':'Bijaya'}
dict2= {'name':'Paudel'}
dict1.update(dict2)
dict1
# Out:
# {'name': 'Paudel'}

# %% [markdown]
# # Kwargs

# %%
#kwargs argument
dict1= {'name':'Bijaya'}
dict2= {'roll':21}
dict3= {'age':26}
dict4= {**dict1, **dict2, **dict3}#this is kwargs
dict4

#why its used
#to update multiple dict
# Out:
# {'name': 'Bijaya', 'roll': 21, 'age': 26}

# %%
# *args, ** kwargs--very imp

# %% [markdown]
# # Merge dict

# %%
#merge two dict

dict1={'name':'Bijaya'}
dict2={'roll':21}
dict3={'age':26}

dict1| dict2| dict3
# Out:
# {'name': 'Bijaya', 'roll': 21, 'age': 26}

# %% [markdown]
# # Sort method in dict

# %%
#sort

student={'b':2,'a':1,'c  ':3}
result=sorted(student)
print(result)
# Out:
# ['a', 'b', 'c  ']

# %% [markdown]
# # Read documentation

# %% [markdown]
# # Class Task

# %%
student_dict= {'name':'Bijaya','age':26,'Faculty':'Student'}
student_dict
# Out:
# {'name': 'Bijaya', 'age': 26, 'Faculty': 'Student'}

# %%
#add new key called phone to existing dict
student_dict['phone']= 9860914199
student_dict
# Out:
# {'name': 'Bijaya', 'age': 26, 'Faculty': 'Student', 'phone': 9860914199}

# %%
student_dict['age']=27
student_dict
# Out:
# {'name': 'Bijaya', 'age': 27, 'Faculty': 'Student', 'phone': 9860914199}

# %%
student_dict
student_dict['city']='Kathmandu'
student_dict
del student_dict['city']
student_dict
# Out:
# {'name': 'Bijaya', 'age': 27, 'Faculty': 'Student', 'phone': 9860914199}

# %%
email_check= student_dict.get('email','There is no email')
print(email_check)
# Out:
# There is no email
