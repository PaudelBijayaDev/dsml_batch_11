# %% [markdown]
# Python data types
# Numeric-integer,float,complex
# dictionary
# boolean
# set
# sequence type-string, list, tuple

# %%
#integer
number=-353456346
type(number)

#floatpie=22/7
type(pie)

#complex
vec=6-3j
type(vec)
# Out:
# complex

# %% [markdown]
# Arithmetic Operations

# %%
a=4
b=2
a//b
# Out:
# 2

# %%
a=1
b=2
c=a//b
print(c)
# Out:
# 0

# %%
a=4
b=5
#addition
print("the addition is",a+b)

#subtraction
print("the subtraction is ",a-b)

#multiplication
print("the multiplication is",a*b)

#division
print("the division is ",a/b)

#modulus-remainder ho
print("the modulus is ",a%b)

#exponentiation
print("the exponentiation is",a**2)

#floor division-quotient ho
print("the floor division is",a//b)
# Out:
# the addition is 9
# the subtraction is  -1
# the multiplication is 20
# the division is  0.8
# the modulus is  4
# the exponentiation is 16
# the floor division is 0

# %% [markdown]
# Type Conversion-int,float,complex,str

# %%
a=45.444
int(a)
# Out:
# 45

# %% [markdown]
# Comparison Operator

# %%
#comparision operators-value will come in boolean expression
#applications-voter, finance services
a=5
b=10

#equal to"=="
print("a is equal to b",a==b)

#not equal to"!="
print("a is not equal to b",a!=b)

#greater than">"
print("a is greater than b",a>b)

#less than"<"
print("a is less than b",a<b)

#greater than or equal to">="
print("a is greater than or equal to",a>=b)

#less than or equal to"<="
print("a is less than or equal to",a<=b)
# Out:
# a is equal to b False
# a is not equal to b True
# a is greater than b False
# a is less than b True
# a is greater than or equal to False
# a is less than or equal to True

# %% [markdown]
# Math functions

# %%
import math
print(math.ceil(44.1))#go to documentation to learn all different kinds of functions that are used in it
print(math.floor(44.3))
print(math.gcd(3,6,9,12))
print(round(22.333,2))

user=640
capacity=128
result=min(user,capacity)
print(result)
# Out:
# 45
# 44
# 3
# 22.33
# 128

# %% [markdown]
# [link text](https://docs.python.org/3/library/math.html)

# %% [markdown]
# Strings

# %%
#string-sequence of characters
#index-position
#postive indexing-start from zero
#negative indexing-start from -1 from last

#technik-range dida first ma postivie indexing,second ma negative indexing use garne smartly

a="hello"
b='hello'
#both will give same value

text1="It's a sunny day"
text2='He said "Hello"'

print(text1)
print(text2)

#used this when we need quotation-so if we need double use single outside,and viceversa

#string concatenation
a="hello"
b="world"
print(a+b)
print(text1+" "+text2)

#repetitiion
print(text1*3)
# Out:
# It's a sunny day
# He said "Hello"
# helloworld
# It's a sunny day He said "Hello"
# It's a sunny dayIt's a sunny dayIt's a sunny day

# %% [markdown]
# indexing`

# %%
data="Python"
print(data[0])
print(data[-6])
# Out:
# P
# P

# %% [markdown]
# slicing-take out value from between

# %%
#data[start:end:step] step is not compulsory

data[1:4:2]

data[0:5:1]#last ko value lidaina-0 vaye first bata start hunx,5 vaye last ko lidaina

#data[1:]
# Out:
# 'Pytho'

# %%
data[1:2]
# Out:
# 'y'

# %%
data6="Hello python"
#ello pytho
data[1:11]
#data[1:-1] is same as above
# Out:
# 'ello pytho'

# %% [markdown]
# len

# %%
len(data)
# Out:
# 12

# %% [markdown]
# replace-how to handle error

# %%
data3="I am a considerable person."
print(data3.replace("considerable", "awesome"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_907/1457597318.py in <cell line: 0>()
#       1 data3="I am a considerable person."
# ----> 2 print(data.replace())
#
# TypeError: replace expected at least 2 arguments, got 0

# %%
#string operations
data6="Hi this is Bijay"

#upper
print(data6.upper())

#lower
print(data6.lower())

#title
print(data6.title())

#strip
clean_name=data6.strip()
print("original name",data6)
print("clean name:",clean_name)#yesko vayena look

#replace
print(data6.replace("i","w"))

#join
words=["I","am","learning","Python."]
print(" ".join(words))
# Out:
# HI THIS IS BIJAY
# hi this is bijay
# Hi This Is Bijay
# original name Hi this is Bijay
# clean name: Hi this is Bijay
# Hw thws ws Bwjay
# I am learning Python.
