# %%
num1=10
num2=5
print(num1+num2)
difference=num1-num2
print(difference)
product=num1*num2
print("the product of two numbers is" {product})
division=num1/num2
print("the division of two numbers is"{division})
# Out:
# 15

# %% [markdown]
# Documentation

# %% [markdown]
# The sum of two numbers is this.
# The product of two numbers is this.
#
# this is the documentation part. so anything written here will not be run and simply it stays here.
# you can also upload image here like this ![image.png](data:image/png;base64,...)

# %% [markdown]
# create a virtual environment
# python -m venv venv #venv is a environment name
#
# activate the environment
# source env #this env is environment name/bin/activate
#
# deactivate
# deactivate

# %% [markdown]
# github
#
# repository-repo-store project
# commit-
# branch
# merge
# clone
# push/pull
