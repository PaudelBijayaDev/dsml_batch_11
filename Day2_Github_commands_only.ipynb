# %% [markdown]
# git hub commands

# %%
#first step create repo
always check git status and then it will show the current status of git
1. git init#if error comes go to privacy and security and add terminal to list manually
2. git add README.md#first there will be error then go to vs code and then create new folder named README.md and then again give the command git add
#README.md then error will go
3.git commit -m "first commit"
  add email and username
  git config --global user.email"your_email@example.com"
  git config --global user.name"Your github username"

  to check git config --global user.email or user.name

  check the username and mail at once-->git config --global --list

4.git branch -M main--->make branch this is very imp--hariyio ayo vane hami tesma xam vaneko ho
5.git remote add origin https://github.com/PaudelBijayaDev/dsml_batch_11.git
6.git push -u origin main
    yesma error ayo vane generate ssh key
      ssh-keygen -t ed25519 -C 'youremail@gmail.com'
7 start ssh agent eval $(ssh-agent -s)
  ssh-add ~/.ssh/id_ed25519
8. git ssh key get and put in deploy section
